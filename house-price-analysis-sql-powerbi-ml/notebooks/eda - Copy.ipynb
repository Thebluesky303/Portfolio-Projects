# %% [markdown]
# # Importing Kaggle dataset

# %%
import kagglehub
path = kagglehub.dataset_download("jakewright/house-price-data")
# Out:
# Downloading to /root/.cache/kagglehub/datasets/jakewright/house-price-data/5.archive...
# 100%|██████████| 48.5M/48.5M [00:00<00:00, 102MB/s]
# Extracting files...

# %% [markdown]
# # Importing dependencies and library

# %%
import os
from pathlib import Path
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# # Loading dataset

# %%
os.listdir(path)
# Out:
# ['kaggle_london_house_price_data.csv',
#  'kaggle_london_house_price_data.parquet']

# %% [markdown]
# On this dataset we get Kaggle dataset link we have two file one is csv and parquet 'kaggle_london_house_price_data.csv' and 'kaggle_london_house_price_data.parquet' both dataset have the same number of columns and features all the value are same but size is different so On this project i used the parquet dataset because lingt weight and suitable for large dataset.

# %%
data_csv = os.path.join(path, 'kaggle_london_house_price_data.csv')

# %%
data_parquet = os.path.join(path, 'kaggle_london_house_price_data.parquet')

# %%
df_csv = pd.read_csv(data_csv)

# %%
df_parquet = pd.read_parquet(data_parquet)

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# ## Understading of dataset

# %%
df_csv.shape
# Out:
# (418201, 28)

# %%
df_parquet.shape
# Out:
# (418201, 28)

# %%
df_csv.head()
# Out:
#                                          fullAddress  postcode  country  \
# 0       Flat 9, 35 Furnival Street, London, EC4A 1JQ  EC4A 1JQ  England
# 1       Flat 6, 35 Furnival Street, London, EC4A 1JQ  EC4A 1JQ  England
# 2  Flat 35, Octavia House, Medway Street, London,...  SW1P 2TA  England
# 3    24 Chester Court, Lomond Grove, London, SE5 7HS   SE5 7HS  England
# 4              18 Alexandra Gardens, London, N10 3RL   N10 3RL  England
#
#   outcode   latitude  longitude  bathrooms  bedrooms  floorAreaSqM  \
# 0    EC4A  51.517282  -0.110314        1.0       1.0          45.0
# 1    EC4A  51.517282  -0.110314        NaN       NaN           NaN
# 2    SW1P  51.495505  -0.132379        2.0       2.0          71.0
# 3     SE5  51.478185  -0.092201        1.0       1.0          64.0
# 4     N10  51.588774  -0.139599        1.0       4.0         137.0
#
#    livingRooms  ... saleEstimate_upperPrice saleEstimate_confidenceLevel  \
# 0          1.0  ...                630000.0                         HIGH
# 1          NaN  ...                660000.0                       MEDIUM
# 2          1.0  ...                834000.0                       MEDIUM
# 3          1.0  ...                407000.0                         HIGH
# 4          2.0  ...               1324000.0                         HIGH
#
#     saleEstimate_ingestedAt  saleEstimate_valueChange.numericChange  \
# 0  2024-10-07T13:26:59.894Z                                244000.0
# 1  2024-10-07T13:26:59.894Z                                425000.0
# 2  2025-01-10T11:04:57.114Z                                 49000.0
# 3  2024-10-07T13:26:59.894Z                                 28000.0
# 4  2024-10-07T13:26:59.894Z                                 81000.0
#
#    saleEstimate_valueChange.percentageChange  \
# 0                                  68.539326
# 1                                 242.857143
# 2                                   6.901408
# 3                                   7.777778
# 4                                   6.864407
#
#    saleEstimate_valueChange.saleDate  history_date  history_price  \
# 0                         2010-03-30    1995-01-02         830000
# 1                         2000-05-26    1995-01-02         830000
# 2                         2019-09-04    1995-01-03         249950
# 3                         2024-01-25    1995-01-03          32000
# 4                         2022-12-14    1995-01-03         133000
#
#    history_percentageChange history_numericChange
# 0                       NaN                   NaN
# 1                       NaN                   NaN
# 2                       NaN                   NaN
# 3                       NaN                   NaN
# 4                       NaN                   NaN
#
# [5 rows x 28 columns]

# %%
df_parquet.head()
# Out:
#                                          fullAddress  postcode  country  \
# 0       Flat 9, 35 Furnival Street, London, EC4A 1JQ  EC4A 1JQ  England
# 1       Flat 6, 35 Furnival Street, London, EC4A 1JQ  EC4A 1JQ  England
# 2  Flat 35, Octavia House, Medway Street, London,...  SW1P 2TA  England
# 3    24 Chester Court, Lomond Grove, London, SE5 7HS   SE5 7HS  England
# 4              18 Alexandra Gardens, London, N10 3RL   N10 3RL  England
#
#   outcode   latitude  longitude  bathrooms  bedrooms  floorAreaSqM  \
# 0    EC4A  51.517282  -0.110314        1.0       1.0          45.0
# 1    EC4A  51.517282  -0.110314        NaN       NaN           NaN
# 2    SW1P  51.495505  -0.132379        2.0       2.0          71.0
# 3     SE5  51.478185  -0.092201        1.0       1.0          64.0
# 4     N10  51.588774  -0.139599        1.0       4.0         137.0
#
#    livingRooms  ... saleEstimate_upperPrice saleEstimate_confidenceLevel  \
# 0          1.0  ...                630000.0                         HIGH
# 1          NaN  ...                660000.0                       MEDIUM
# 2          1.0  ...                834000.0                       MEDIUM
# 3          1.0  ...                407000.0                         HIGH
# 4          2.0  ...               1324000.0                         HIGH
#
#     saleEstimate_ingestedAt  saleEstimate_valueChange.numericChange  \
# 0  2024-10-07T13:26:59.894Z                                244000.0
# 1  2024-10-07T13:26:59.894Z                                425000.0
# 2  2025-01-10T11:04:57.114Z                                 49000.0
# 3  2024-10-07T13:26:59.894Z                                 28000.0
# 4  2024-10-07T13:26:59.894Z                                 81000.0
#
#    saleEstimate_valueChange.percentageChange  \
# 0                                  68.539326
# 1                                 242.857143
# 2                                   6.901408
# 3                                   7.777778
# 4                                   6.864407
#
#    saleEstimate_valueChange.saleDate  history_date  history_price  \
# 0                         2010-03-30    1995-01-02         830000
# 1                         2000-05-26    1995-01-02         830000
# 2                         2019-09-04    1995-01-03         249950
# 3                         2024-01-25    1995-01-03          32000
# 4                         2022-12-14    1995-01-03         133000
#
#    history_percentageChange history_numericChange
# 0                       NaN                   NaN
# 1                       NaN                   NaN
# 2                       NaN                   NaN
# 3                       NaN                   NaN
# 4                       NaN                   NaN
#
# [5 rows x 28 columns]

# %%
df_parquet.tail()
# Out:
#                                               fullAddress  postcode  country  \
# 418196                   9 Harvard Road, London, SE13 6SE  SE13 6SE  England
# 418197  Lower Ground Floor Flat 5, Northwood Hall, Hor...    N6 5PE  England
# 418198                   17 Merritt Road, London, SE4 1DU   SE4 1DU  England
# 418199                   15 Chester Row, London, SW1W 9JF  SW1W 9JF  England
# 418200                 56 Whiteley Road, London, SE19 1JT  SE19 1JT  England
#
#        outcode   latitude  longitude  bathrooms  bedrooms  floorAreaSqM  \
# 418196    SE13  51.452919  -0.010221        2.0       3.0         123.0
# 418197      N6  51.571692  -0.137007        1.0       2.0          60.0
# 418198     SE4  51.456054  -0.035073        2.0       3.0         100.0
# 418199    SW1W  51.493587  -0.152122        3.0       4.0         218.0
# 418200    SE19  51.424412  -0.090256        1.0       5.0         154.0
#
#         livingRooms  ... saleEstimate_upperPrice saleEstimate_confidenceLevel  \
# 418196          2.0  ...                711000.0                         HIGH
# 418197          1.0  ...                473000.0                         HIGH
# 418198          1.0  ...                853000.0                         HIGH
# 418199          2.0  ...               5975000.0                       MEDIUM
# 418200          2.0  ...               1031000.0                         HIGH
#
#          saleEstimate_ingestedAt  saleEstimate_valueChange.numericChange  \
# 418196  2025-01-10T11:04:57.114Z                                 27000.0
# 418197  2025-01-10T11:04:57.114Z                                 10000.0
# 418198  2025-01-10T11:04:57.114Z                                 38000.0
# 418199  2025-01-10T11:04:57.114Z                               -818000.0
# 418200  2025-01-10T11:04:57.114Z                                 55000.0
#
#         saleEstimate_valueChange.percentageChange  \
# 418196                                   4.153846
# 418197                                   2.272727
# 418198                                   4.909561
# 418199                                 -13.088000
# 418200                                   5.876011
#
#         saleEstimate_valueChange.saleDate  history_date  history_price  \
# 418196                         2024-09-27    2024-09-27         650000
# 418197                         2024-09-27    2024-09-27         440000
# 418198                         2024-09-27    2024-09-27         774000
# 418199                         2024-09-27    2024-09-27        6250000
# 418200                         2024-09-27    2024-09-27         927500
#
#         history_percentageChange history_numericChange
# 418196                 17.117117               95000.0
# 418197                  2.325581               10000.0
# 418198                128.655835              435500.0
# 418199                 73.611111             2650000.0
# 418200                692.735043              810500.0
#
# [5 rows x 28 columns]

# %%
df_csv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418201 entries, 0 to 418200
# Data columns (total 28 columns):
#  #   Column                                     Non-Null Count   Dtype
# ---  ------                                     --------------   -----
#  0   fullAddress                                418201 non-null  object
#  1   postcode                                   418201 non-null  object
#  2   country                                    418201 non-null  object
#  3   outcode                                    418201 non-null  object
#  4   latitude                                   418201 non-null  float64
#  5   longitude                                  418201 non-null  float64
#  6   bathrooms                                  340270 non-null  float64
#  7   bedrooms                                   377665 non-null  float64
#  8   floorAreaSqM                               392991 non-null  float64
#  9   livingRooms                                357701 non-null  float64
#  10  tenure                                     406689 non-null  object
#  11  propertyType                               417065 non-null  object
#  12  currentEnergyRating                        333675 non-null  object
#  13  rentEstimate_lowerPrice                    416460 non-null  float64
#  14  rentEstimate_currentPrice                  416460 non-null  float64
#  15  rentEstimate_upperPrice                    416460 non-null  float64
#  16  saleEstimate_lowerPrice                    417561 non-null  float64
#  17  saleEstimate_currentPrice                  417561 non-null  float64
#  18  saleEstimate_upperPrice                    417561 non-null  float64
#  19  saleEstimate_confidenceLevel               417561 non-null  object
#  20  saleEstimate_ingestedAt                    417561 non-null  object
#  21  saleEstimate_valueChange.numericChange     417561 non-null  float64
#  22  saleEstimate_valueChange.percentageChange  417561 non-null  float64
#  23  saleEstimate_valueChange.saleDate          417561 non-null  object
#  24  history_date                               418201 non-null  object
#  25  history_price                              418201 non-null  int64
#  26  history_percentageChange                   237982 non-null  float64
#  27  history_numericChange                      237982 non-null  float64
# dtypes: float64(16), int64(1), object(11)
# memory usage: 89.3+ MB

# %%
df_parquet.info()

# %% [markdown]
# ### Converting date time

# %%
cols = [
    'saleEstimate_ingestedAt',
    'saleEstimate_valueChange.saleDate',
    'history_date'
]

for col in cols:
    print(f"{col}: ")
    print("Sample values:")
    print(df_parquet[col].head(10))
    print("\nUnique sample values:")
    print(df_parquet[col].dropna().unique()[:10])
# Out:
# saleEstimate_ingestedAt:
# Sample values:
# 0    2024-10-07T13:26:59.894Z
# 1    2024-10-07T13:26:59.894Z
# 2    2025-01-10T11:04:57.114Z
# 3    2024-10-07T13:26:59.894Z
# 4    2024-10-07T13:26:59.894Z
# 5    2024-10-07T13:26:59.894Z
# 6    2024-10-07T13:26:59.894Z
# 7    2025-01-10T11:04:57.114Z
# 8    2024-10-07T13:26:59.894Z
# 9    2025-01-10T11:04:57.114Z
# Name: saleEstimate_ingestedAt, dtype: object
#
# Unique sample values:
# ['2024-10-07T13:26:59.894Z' '2025-01-10T11:04:57.114Z'
#  '2025-02-06T14:05:28.374Z' '2024-11-05T11:25:48.799Z']
# saleEstimate_valueChange.saleDate:
# Sample values:
# 0    2010-03-30
# 1    2000-05-26
# 2    2019-09-04
# 3    2024-01-25
# 4    2022-12-14
# 5    2021-09-30
# 6    2021-12-06
# 7    2016-09-27
# 8    2022-02-10
# 9    2022-12-14
# Name: saleEstimate_valueChange.saleDate, dtype: object
#
# Unique sample values:
# ['2010-03-30' '2000-05-26' '2019-09-04' '2024-01-25' '2022-12-14'
#  '2021-09-30' '2021-12-06' '2016-09-27' '2022-02-10' '2024-04-19']
# history_date:
# Sample values:
# 0    1995-01-02
# 1    1995-01-02
# 2    1995-01-03
# 3    1995-01-03
# 4    1995-01-03
# 5    1995-01-03
# 6    1995-01-03
# 7    1995-01-03
# 8    1995-01-03
# 9    1995-01-03
# Name: history_date, dtype: object
#
# Unique sample values:
# ['1995-01-02' '1995-01-03' '1995-01-04' '1995-01-05' '1995-01-06'
#  '1995-01-09' '1995-01-10' '1995-01-11' '1995-01-12' '1995-01-13']

# %%
df_parquet['saleEstimate_ingestedAt'] = pd.to_datetime(df_parquet['saleEstimate_ingestedAt'], errors='coerce')
df_parquet['saleEstimate_valueChange.saleDate'] = pd.to_datetime(df_parquet['saleEstimate_valueChange.saleDate'], errors='coerce')
df_parquet['history_date'] = pd.to_datetime(df_parquet['history_date'], errors='coerce')

# %%
df_parquet.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418201 entries, 0 to 418200
# Data columns (total 28 columns):
#  #   Column                                     Non-Null Count   Dtype
# ---  ------                                     --------------   -----
#  0   fullAddress                                418201 non-null  object
#  1   postcode                                   418201 non-null  object
#  2   country                                    418201 non-null  object
#  3   outcode                                    418201 non-null  object
#  4   latitude                                   418201 non-null  float64
#  5   longitude                                  418201 non-null  float64
#  6   bathrooms                                  340270 non-null  float64
#  7   bedrooms                                   377665 non-null  float64
#  8   floorAreaSqM                               392991 non-null  float64
#  9   livingRooms                                357701 non-null  float64
#  10  tenure                                     406689 non-null  object
#  11  propertyType                               417065 non-null  object
#  12  currentEnergyRating                        333675 non-null  object
#  13  rentEstimate_lowerPrice                    416460 non-null  float64
#  14  rentEstimate_currentPrice                  416460 non-null  float64
#  15  rentEstimate_upperPrice                    416460 non-null  float64
#  16  saleEstimate_lowerPrice                    417561 non-null  float64
#  17  saleEstimate_currentPrice                  417561 non-null  float64
#  18  saleEstimate_upperPrice                    417561 non-null  float64
#  19  saleEstimate_confidenceLevel               417561 non-null  object
#  20  saleEstimate_ingestedAt                    417561 non-null  datetime64[ns, UTC]
#  21  saleEstimate_valueChange.numericChange     417561 non-null  float64
#  22  saleEstimate_valueChange.percentageChange  417561 non-null  float64
#  23  saleEstimate_valueChange.saleDate          417561 non-null  datetime64[ns]
#  24  history_date                               418201 non-null  datetime64[ns]
#  25  history_price                              418201 non-null  int64
#  26  history_percentageChange                   237982 non-null  float64
#  27  history_numericChange                      237982 non-null  float64
# dtypes: datetime64[ns, UTC](1), datetime64[ns](2), float64(16), int64(1), object(8)
# memory usage: 89.3+ MB

# %% [markdown]
# ### Missing values analysis

# %%
df_parquet.isnull().sum()
# Out:
# fullAddress                                       0
# postcode                                          0
# country                                           0
# outcode                                           0
# latitude                                          0
# longitude                                         0
# bathrooms                                     77931
# bedrooms                                      40536
# floorAreaSqM                                  25210
# livingRooms                                   60500
# tenure                                        11512
# propertyType                                   1136
# currentEnergyRating                           84526
# rentEstimate_lowerPrice                        1741
# rentEstimate_currentPrice                      1741
# rentEstimate_upperPrice                        1741
# saleEstimate_lowerPrice                         640
# saleEstimate_currentPrice                       640
# saleEstimate_upperPrice                         640
# saleEstimate_confidenceLevel                    640
# saleEstimate_ingestedAt                         640
# saleEstimate_valueChange.numericChange          640
# saleEstimate_valueChange.percentageChange       640
# saleEstimate_valueChange.saleDate               640
# history_date                                      0
# history_price                                     0
# history_percentageChange                     180219
# history_numericChange                        180219
# dtype: int64

# %% [markdown]
# 'fullAddress' is droped because it does not need us.

# %%
df_parquet.drop(columns=['fullAddress'], inplace=True)

# %%
missing = df_parquet.isnull().sum().sort_values(ascending=False)
missing_percent = (df_parquet.isnull().mean() * 100).sort_values(ascending=False)

missing_df = pd.DataFrame({
    'Missing Count': missing,
    'Missing %': missing_percent
})

print(missing_df)
# Out:
#                                            Missing Count  Missing %
# history_numericChange                             180219  43.093871
# history_percentageChange                          180219  43.093871
# currentEnergyRating                                84526  20.211812
# bathrooms                                          77931  18.634819
# livingRooms                                        60500  14.466728
# bedrooms                                           40536   9.692947
# floorAreaSqM                                       25210   6.028202
# tenure                                             11512   2.752743
# rentEstimate_lowerPrice                             1741   0.416307
# rentEstimate_upperPrice                             1741   0.416307
# rentEstimate_currentPrice                           1741   0.416307
# propertyType                                        1136   0.271640
# saleEstimate_confidenceLevel                         640   0.153036
# saleEstimate_ingestedAt                              640   0.153036
# saleEstimate_valueChange.numericChange               640   0.153036
# saleEstimate_valueChange.saleDate                    640   0.153036
# saleEstimate_upperPrice                              640   0.153036
# saleEstimate_lowerPrice                              640   0.153036
# saleEstimate_currentPrice                            640   0.153036
# saleEstimate_valueChange.percentageChange            640   0.153036
# longitude                                              0   0.000000
# country                                                0   0.000000
# outcode                                                0   0.000000
# postcode                                               0   0.000000
# latitude                                               0   0.000000
# history_price                                          0   0.000000
# history_date                                           0   0.000000

# %% [markdown]
# ## Descriptive Analysis

# %%
df_parquet.describe()
# Out:
#             latitude      longitude      bathrooms       bedrooms  \
# count  418201.000000  418201.000000  340270.000000  377665.000000
# mean       51.507522      -0.101426       1.444265       2.474884
# std         0.056171       0.086930       0.724478       1.160506
# min        51.385708      -0.347055       1.000000       1.000000
# 25%        51.464315      -0.155996       1.000000       2.000000
# 50%        51.501581      -0.108482       1.000000       2.000000
# 75%        51.548515      -0.043582       2.000000       3.000000
# max        51.665823       0.139249       9.000000       9.000000
#
#         floorAreaSqM    livingRooms  rentEstimate_lowerPrice  \
# count  392991.000000  357701.000000            416460.000000
# mean       98.926543       1.282275              3299.054171
# std        55.938911       0.574412              3168.625404
# min        10.000000       1.000000               300.000000
# 25%        63.000000       1.000000              1800.000000
# 50%        84.000000       1.000000              2350.000000
# 75%       116.000000       1.000000              3550.000000
# max       500.000000       9.000000            111500.000000
#
#        rentEstimate_currentPrice  rentEstimate_upperPrice  \
# count              416460.000000            416460.000000
# mean                 3639.487466              3980.117298
# std                  3487.801945              3808.508868
# min                   350.000000               400.000000
# 25%                  1950.000000              2100.000000
# 50%                  2600.000000              2850.000000
# 75%                  3950.000000              4300.000000
# max                121200.000000            130900.000000
#
#        saleEstimate_lowerPrice  saleEstimate_currentPrice  \
# count             4.175610e+05               4.175610e+05
# mean              8.312692e+05               9.045188e+05
# std               8.088434e+05               9.202917e+05
# min               8.100000e+04               8.900000e+04
# 25%               4.160000e+05               4.460000e+05
# 50%               5.810000e+05               6.220000e+05
# 75%               9.130000e+05               9.840000e+05
# max               2.337600e+07               2.922000e+07
#
#        saleEstimate_upperPrice  saleEstimate_valueChange.numericChange  \
# count             4.175610e+05                            4.175610e+05
# mean              9.777633e+05                            2.886077e+04
# std               1.037913e+06                            1.080893e+06
# min               9.300000e+04                           -1.053770e+08
# 25%               4.750000e+05                            1.100000e+04
# 50%               6.630000e+05                            3.500000e+04
# 75%               1.054000e+06                            8.600000e+04
# max               3.506400e+07                            2.268100e+07
#
#        saleEstimate_valueChange.percentageChange  history_price  \
# count                              417561.000000   4.182010e+05
# mean                                   29.278605   6.395840e+05
# std                                   362.350731   1.327933e+06
# min                                   -99.763196   1.000000e+04
# 25%                                     2.105263   2.280000e+05
# 50%                                     6.260870   4.000000e+05
# 75%                                    13.554987   6.650000e+05
# max                                 48860.000000   1.058000e+08
#
#        history_percentageChange  history_numericChange
# count             237982.000000           2.379820e+05
# mean                 105.877778           2.528741e+05
# std                  338.849944           8.024032e+05
# min                  -99.890110          -7.390000e+07
# 25%                   17.833333           4.849500e+04
# 50%                   52.857143           1.300000e+05
# 75%                  114.285714           2.870000e+05
# max                48800.770000           6.382000e+07

# %%
df_parquet.describe().T
# Out:
#                                               count  \
# latitude                                   418201.0
# longitude                                  418201.0
# bathrooms                                  340270.0
# bedrooms                                   377665.0
# floorAreaSqM                               392991.0
# livingRooms                                357701.0
# rentEstimate_lowerPrice                    416460.0
# rentEstimate_currentPrice                  416460.0
# rentEstimate_upperPrice                    416460.0
# saleEstimate_lowerPrice                    417561.0
# saleEstimate_currentPrice                  417561.0
# saleEstimate_upperPrice                    417561.0
# saleEstimate_valueChange.numericChange     417561.0
# saleEstimate_valueChange.percentageChange  417561.0
# saleEstimate_valueChange.saleDate            417561
# history_date                                 418201
# history_price                              418201.0
# history_percentageChange                   237982.0
# history_numericChange                      237982.0
#
#                                                                     mean  \
# latitude                                                       51.507522
# longitude                                                      -0.101426
# bathrooms                                                       1.444265
# bedrooms                                                        2.474884
# floorAreaSqM                                                   98.926543
# livingRooms                                                     1.282275
# rentEstimate_lowerPrice                                      3299.054171
# rentEstimate_currentPrice                                    3639.487466
# rentEstimate_upperPrice                                      3980.117298
# saleEstimate_lowerPrice                                    831269.215755
# saleEstimate_currentPrice                                  904518.762528
# saleEstimate_upperPrice                                    977763.270516
# saleEstimate_valueChange.numericChange                      28860.767648
# saleEstimate_valueChange.percentageChange                      29.278605
# saleEstimate_valueChange.saleDate          2021-11-27 12:28:40.195132928
# history_date                               2013-08-27 20:59:16.846587904
# history_price                                               639584.00439
# history_percentageChange                                      105.877778
# history_numericChange                                      252874.079405
#
#                                                            min  \
# latitude                                             51.385708
# longitude                                            -0.347055
# bathrooms                                                  1.0
# bedrooms                                                   1.0
# floorAreaSqM                                              10.0
# livingRooms                                                1.0
# rentEstimate_lowerPrice                                  300.0
# rentEstimate_currentPrice                                350.0
# rentEstimate_upperPrice                                  400.0
# saleEstimate_lowerPrice                                81000.0
# saleEstimate_currentPrice                              89000.0
# saleEstimate_upperPrice                                93000.0
# saleEstimate_valueChange.numericChange            -105377000.0
# saleEstimate_valueChange.percentageChange           -99.763196
# saleEstimate_valueChange.saleDate          1995-01-06 00:00:00
# history_date                               1995-01-02 00:00:00
# history_price                                          10000.0
# history_percentageChange                             -99.89011
# history_numericChange                              -73900000.0
#
#                                                            25%  \
# latitude                                             51.464315
# longitude                                            -0.155996
# bathrooms                                                  1.0
# bedrooms                                                   2.0
# floorAreaSqM                                              63.0
# livingRooms                                                1.0
# rentEstimate_lowerPrice                                 1800.0
# rentEstimate_currentPrice                               1950.0
# rentEstimate_upperPrice                                 2100.0
# saleEstimate_lowerPrice                               416000.0
# saleEstimate_currentPrice                             446000.0
# saleEstimate_upperPrice                               475000.0
# saleEstimate_valueChange.numericChange                 11000.0
# saleEstimate_valueChange.percentageChange             2.105263
# saleEstimate_valueChange.saleDate          2021-07-08 00:00:00
# history_date                               2005-03-17 00:00:00
# history_price                                         228000.0
# history_percentageChange                             17.833333
# history_numericChange                                  48495.0
#
#                                                            50%  \
# latitude                                             51.501581
# longitude                                            -0.108482
# bathrooms                                                  1.0
# bedrooms                                                   2.0
# floorAreaSqM                                              84.0
# livingRooms                                                1.0
# rentEstimate_lowerPrice                                 2350.0
# rentEstimate_currentPrice                               2600.0
# rentEstimate_upperPrice                                 2850.0
# saleEstimate_lowerPrice                               581000.0
# saleEstimate_currentPrice                             622000.0
# saleEstimate_upperPrice                               663000.0
# saleEstimate_valueChange.numericChange                 35000.0
# saleEstimate_valueChange.percentageChange              6.26087
# saleEstimate_valueChange.saleDate          2022-11-30 00:00:00
# history_date                               2016-01-21 00:00:00
# history_price                                         400000.0
# history_percentageChange                             52.857143
# history_numericChange                                 130000.0
#
#                                                            75%  \
# latitude                                             51.548515
# longitude                                            -0.043582
# bathrooms                                                  2.0
# bedrooms                                                   3.0
# floorAreaSqM                                             116.0
# livingRooms                                                1.0
# rentEstimate_lowerPrice                                 3550.0
# rentEstimate_currentPrice                               3950.0
# rentEstimate_upperPrice                                 4300.0
# saleEstimate_lowerPrice                               913000.0
# saleEstimate_currentPrice                             984000.0
# saleEstimate_upperPrice                              1054000.0
# saleEstimate_valueChange.numericChange                 86000.0
# saleEstimate_valueChange.percentageChange            13.554987
# saleEstimate_valueChange.saleDate          2023-10-04 00:00:00
# history_date                               2022-07-29 00:00:00
# history_price                                         665000.0
# history_percentageChange                            114.285714
# history_numericChange                                 287000.0
#
#                                                            max             std
# latitude                                             51.665823        0.056171
# longitude                                             0.139249         0.08693
# bathrooms                                                  9.0        0.724478
# bedrooms                                                   9.0        1.160506
# floorAreaSqM                                             500.0       55.938911
# livingRooms                                                9.0        0.574412
# rentEstimate_lowerPrice                               111500.0     3168.625404
# rentEstimate_currentPrice                             121200.0     3487.801945
# rentEstimate_upperPrice                               130900.0     3808.508868
# saleEstimate_lowerPrice                             23376000.0   808843.379724
# saleEstimate_currentPrice                           29220000.0   920291.664239
# saleEstimate_upperPrice                             35064000.0  1037913.051264
# saleEstimate_valueChange.numericChange              22681000.0  1080893.492314
# saleEstimate_valueChange.percentageChange              48860.0      362.350731
# saleEstimate_valueChange.saleDate          2024-09-27 00:00:00             NaN
# history_date                               2024-09-27 00:00:00             NaN
# history_price                                      105800000.0  1327933.407839
# history_percentageChange                              48800.77      338.849944
# history_numericChange                               63820000.0   802403.242233

# %% [markdown]
# # Save file for visualization.

# %%
save_dir = Path("../data")
save_dir.mkdir(parents=True, exist_ok=True)

save_path = save_dir / "house_price_data.csv"

df_parquet.to_csv(save_path, index=False)

print("Saved to:", save_path.resolve())
# Out:
# Saved to: /data/house_price_data.csv

# %%
# %run eda.ipynb
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/IPython/core/magics/execution.py in run(self, parameter_s, runner, file_finder)
#     713             fpath = arg_lst[0]
# --> 714             filename = file_finder(fpath)
#     715         except IndexError:
#
# /usr/local/lib/python3.12/dist-packages/IPython/utils/path.py in get_py_filename(name, force_win32)
#     108     else:
# --> 109         raise IOError('File `%r` not found.' % name)
#     110
#
# OSError: File `'eda.ipynb.py'` not found.
#
# During handling of the above exception, another exception occurred:
#
# Exception                                 Traceback (most recent call last)
# /tmp/ipykernel_8037/1586951015.py in <cell line: 0>()
# ----> 1 get_ipython().run_line_magic('run', 'eda.ipynb')
#
# /usr/local/lib/python3.12/dist-packages/IPython/core/interactiveshell.py in run_line_magic(self, magic_name, line, _stack_depth)
#    2416                 kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2417             with self.builtin_trap:
# -> 2418                 result = fn(*args, **kwargs)
#    2419             return result
#    2420
#
# <decorator-gen-52> in run(self, parameter_s, runner, file_finder)
#
# /usr/local/lib/python3.12/dist-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# /usr/local/lib/python3.12/dist-packages/IPython/core/magics/execution.py in run(self, parameter_s, runner, file_finder)
#     723             if os.name == 'nt' and re.match(r"^'.*'$",fpath):
#     724                 warn('For Windows, use double quotes to wrap a filename: %run "mypath\\myfile.py"')
# --> 725             raise Exception(msg)
#     726         except TypeError:
#     727             if fpath in sys.meta_path:
#
# Exception: File `'eda.ipynb.py'` not found.

# %%
import pandas as pd
df = pd.read_csv("data.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_8037/3422652871.py in <cell line: 0>()
#       1 import pandas as pd
# ----> 2 df = pd.read_csv("data.csv")
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1024     kwds.update(kwds_defaults)
#    1025
# -> 1026     return _read(filepath_or_buffer, kwds)
#    1027
#    1028
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     618
#     619     # Create the parser.
# --> 620     parser = TextFileReader(filepath_or_buffer, **kwds)
#     621
#     622     if chunksize or iterator:
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#    1618
#    1619         self.handles: IOHandles | None = None
# -> 1620         self._engine = self._make_engine(f, self.engine)
#    1621
#    1622     def close(self) -> None:
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in _make_engine(self, f, engine)
#    1878                 if "b" not in mode:
#    1879                     mode += "b"
# -> 1880             self.handles = get_handle(
#    1881                 f,
#    1882                 mode,
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     871         if ioargs.encoding and "b" not in ioargs.mode:
#     872             # Encoding
# --> 873             handle = open(
#     874                 handle,
#     875                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data.csv'
